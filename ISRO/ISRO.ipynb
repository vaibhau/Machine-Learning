# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/DBDA/Machine Learning/ISRO/ISRO.csv',encoding="latin-1")
df
# Out:
#      SL No                      Launch Date Launch Vehicle  \
# 0      125                        Aditya-L1      02-Sep-23
# 1      124                    Chandrayaan-3      14-Jul-23
# 2      123                           NVS-01      29-May-23
# 3      122                           EOS-07      10-Feb-23
# 4      121                          Thybolt      26-Nov-22
# ..     ...                              ...            ...
# 120      5           Rohini Satellite RS-D1      31-May-81
# 121      4            Rohini Satellite RS-1      18-Jul-80
# 122      3  Rohini Technology Payload (RTP)      10-Aug-79
# 123      2                       Bhaskara-I      07-Jun-79
# 124      1                        Aryabhata      19-Apr-75
#
#                     Launch Vehicle.1             Orbit Type  \
# 0         PSLV-C57/Aditya-L1 Mission                  Lunar
# 1    LVM3 M4 / Chandrayaan-3 Mission                  Lunar
# 2            GSLV-F12/NVS-01 Mission                    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SL No             125 non-null    int64
#  1   Launch Date       125 non-null    object
#  2   Launch Vehicle    125 non-null    object
#  3   Launch Vehicle.1  125 non-null    object
#  4   Orbit Type        104 non-null    object
#  5   Application       121 non-null    object
#  6   Remarks           125 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 7.0+ KB

# %%
df.describe()
# Out:
#             SL No
# count  125.000000
# mean    63.000000
# std     36.228442
# min      1.000000
# 25%     32.000000
# 50%     63.000000
# 75%     94.000000
# max    125.000000

# %%
df.isnull().sum()
# Out:
# SL No                0
# Launch Date          0
# Launch Vehicle       0
# Launch Vehicle.1     0
# Orbit Type          21
# Application          4
# Remarks              0
# dtype: int64

# %%
df.nunique()
# Out:
# SL No               125
# Launch Date         123
# Launch Vehicle      112
# Launch Vehicle.1    109
# Orbit Type            7
# Application          15
# Remarks               5
# dtype: int64

# %%
sns.countplot(data = df, x='Remarks')
plt.title('Launch Success Rate')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df, x='Orbit Type', order=df['Orbit Type'].value_counts().index)
plt.title('Distribution of Mission Orbit Types')
plt.xlabel('Orbit Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
application_counts = df['Application'].value_counts()

# %%
sns.barplot(x=application_counts.index, y=application_counts.values)
plt.title('Distribution of Mission Applications')
plt.xlabel('Mission Application')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
